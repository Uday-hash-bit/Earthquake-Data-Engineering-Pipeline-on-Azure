# %%
# Mount ADLS Gen2
# Required each time the cluster is restarted which should be only on the first notebook as they run in order

tiers = ["bronze", "silver", "gold"]
adls_paths = {tier: f"abfss://{tier}@earthquakeproject123.dfs.core.windows.net/" for tier in tiers}

# Accessing paths
bronze_adls = adls_paths["bronze"]
silver_adls = adls_paths["silver"]
gold_adls = adls_paths["gold"] 

dbutils.fs.ls(bronze_adls)
dbutils.fs.ls(silver_adls)
dbutils.fs.ls(gold_adls)
# Out:
# []

# %%
import requests
import json
from datetime import date, timedelta

# %%
# Data Factory
# Get base parameters
dbutils.widgets.text("start_date", "")
dbutils.widgets.text("end_date", "")
start_date = dbutils.widgets.get("start_date")
end_date = dbutils.widgets.get("end_date")

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

try:
    # Make the GET request to fetch data
    response = requests.get(url)

    # Check if the request was successful
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    data = response.json().get('features', [])

    if not data:
        print("No data returned for the specified date range.")
    else:
        # Specify the ADLS path
        file_path = f"{bronze_adls}/{start_date}_earthquake_data.json"

        # Save the JSON data
        json_data = json.dumps(data, indent=4)
        dbutils.fs.put(file_path, json_data, overwrite=True)
        print(f"Data successfully saved to {file_path}")
except requests.exceptions.RequestException as e:
    print(f"Error fetching data from API: {e}")
# Out:
# Wrote 252675 bytes.
# Data successfully saved to abfss://bronze@earthquakeproject123.dfs.core.windows.net//2025-12-21_earthquake_data.json

# %%
data
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 2.1,
#    'place': '58 km S of Whites City, New Mexico',
#    'time': 1766360318551,
#    'updated': 1766383619946,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025zbqbzw',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025zbqbzw&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 68,
#    'net': 'tx',
#    'code': '2025zbqbzw',
#    'ids': ',tx2025zbqbzw,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 31,
#    'dmin': 0.1,
#    'rms': 0.3,
#    'gap': 97,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 58 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.349, 31.653, 4.4806]},
#   'id': 'tx2025zbqbzw'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.86,
#    'place': '3 km WSW of Pāhala, Hawaii',
#    'time': 1766360278560,
#    'updated': 1766360513250,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv74857937',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74857937&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 53,
#    'net': 'hv',
#    'code': '74857937',
#    'ids': ',hv74857937,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 37,
#    'dmin': 0.05669,
#    'rms': 0.170000002,
#    'gap': 135,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 3 km WSW of Pāhala, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.508834838867, 19.1921672821045, 29.6100006103516]},
#   'id': 'hv74857937'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': '0 km E of Iwaizumi, Japan',
#    'time': 1766359985004,
#    'updated': 1766363103040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwed',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwed&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 312,
#    'net': 'us',
#    'code': '6000rwed',
#    'ids': ',us6000rwed,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 38,
#    'dmin': 1.096,
#    'rms': 0.57,
#    'gap': 175,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - 0 km E of Iwaizumi, Japan'},
#   'geometry': {'type': 'Point', 'coordinates': [141.8085, 39.8511, 63.558]},
#   'id': 'us6000rwed'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.3,
#    'place': '157 km SSW of Kokopo, Papua New Guinea',
#    'time': 1766358447277,
#    'updated': 1766359606040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwea',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwea&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 432,
#    'net': 'us',
#    'code': '6000rwea',
#    'ids': ',usauto6000rwea,us6000rwea,',
#    'sources': ',usauto,us,',
#    'types': ',internal-moment-tensor,origin,phase-data,',
#    'nst': 41,
#    'dmin': 1.52,
#    'rms': 1.19,
#    'gap': 83,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.3 - 157 km SSW of Kokopo, Papua New Guinea'},
#   'geometry': {'type': 'Point', 'coordinates': [151.7103, -5.6522, 9.958]},
#   'id': 'us6000rwea'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.29,
#    'place': '15 km SSE of Livermore, CA',
#    'time': 1766358387370,
#    'updated': 1766358484428,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284426',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284426&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'nc',
#    'code': '75284426',
#    'ids': ',nc75284426,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.3005,
#    'rms': 0.16,
#    'gap': 223,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 15 km SSE of Livermore, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.678169250488, 37.5714988708496, 8.89999961853027]},
#   'id': 'nc75284426'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.63,
#    'place': '5 km SW of Ridgemark, CA',
#    'time': 1766358212720,
#    'updated': 1766358635548,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284421',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284421&format=geojson',
#    'felt': 1,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 107,
#    'net': 'nc',
#    'code': '75284421',
#    'ids': ',nc75284421,',
#    'sources': ',nc,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 52,
#    'dmin': 0.03657,
#    'rms': 0.18,
#    'gap': 31,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 5 km SW of Ridgemark, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.408500671387, 36.783332824707, 6.88000011444092]},
#   'id': 'nc75284421'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.26,
#    'place': '7 km S of Ojai, CA',
#    'time': 1766358153180,
#    'updated': 1766358818370,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144847',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144847&format=geojson',
#    'felt': 2,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 79,
#    'net': 'ci',
#    'code': '41144847',
#    'ids': ',ci41144847,',
#    'sources': ',ci,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 68,
#    'dmin': 0.04332,
#    'rms': 0.32,
#    'gap': 58,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 7 km S of Ojai, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.248333333333, 34.3851666666667, 6.9]},
#   'id': 'ci41144847'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.81,
#    'place': '18 km W of Searles Valley, CA',
#    'time': 1766357929230,
#    'updated': 1766358574230,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144839',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144839&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'ci',
#    'code': '41144839',
#    'ids': ',ci41144839,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 39,
#    'dmin': 0.03586,
#    'rms': 0.14,
#    'gap': 60,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 18 km W of Searles Valley, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.599166666667, 35.7798333333333, 6.76]},
#   'id': 'ci41144839'},
#  {'type': 'Feature',
#   'properties': {'mag': 2,
#    'place': '24 km SSW of Westbrook, Texas',
#    'time': 1766357747263,
#    'updated': 1766362697702,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025zboqyx',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025zboqyx&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 62,
#    'net': 'tx',
#    'code': '2025zboqyx',
#    'ids': ',tx2025zboqyx,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 20,
#    'dmin': 0.2,
#    'rms': 0.4,
#    'gap': 81,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 24 km SSW of Westbrook, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.073, 32.14, 2.9453]},
#   'id': 'tx2025zboqyx'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.81,
#    'place': '3 km N of Pinnacles, CA',
#    'time': 1766357537920,
#    'updated': 1766357635669,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284401',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284401&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'nc',
#    'code': '75284401',
#    'ids': ',nc75284401,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 20,
#    'dmin': 0.03632,
#    'rms': 0.16,
#    'gap': 69,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 3 km N of Pinnacles, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.14282989502, 36.5596656799316, 8.60999965667725]},
#   'id': 'nc75284401'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.06,
#    'place': '21 km ENE of Coachella, CA',
#    'time': 1766357448800,
#    'updated': 1766357664310,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144823',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144823&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 17,
#    'net': 'ci',
#    'code': '41144823',
#    'ids': ',ci41144823,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 41,
#    'dmin': 0.1193,
#    'rms': 0.15,
#    'gap': 64,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 21 km ENE of Coachella, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.982833333333, 33.7746666666667, 2.34]},
#   'id': 'ci41144823'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.37,
#    'place': '4 km SE of San Ramon, CA',
#    'time': 1766356569030,
#    'updated': 1766374837074,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284391',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284391&format=geojson',
#    'felt': 1,
#    'cdi': 1,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 87,
#    'net': 'nc',
#    'code': '75284391',
#    'ids': ',nc75284391,',
#    'sources': ',nc,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 34,
#    'dmin': 0.09542,
#    'rms': 0.08,
#    'gap': 44,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 4 km SE of San Ramon, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.945503234863, 37.7501678466797, 8.6899995803833]},
#   'id': 'nc75284391'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.7,
#    'place': '270 km N of Saipan, Northern Mariana Islands',
#    'time': 1766356020420,
#    'updated': 1766359821040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwe1',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwe1&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 340,
#    'net': 'us',
#    'code': '6000rwe1',
#    'ids': ',us6000rwe1,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 60,
#    'dmin': 16.096,
#    'rms': 0.77,
#    'gap': 74,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.7 - 270 km N of Saipan, Northern Mariana Islands'},
#   'geometry': {'type': 'Point', 'coordinates': [146.0291, 17.6424, 156.226]},
#   'id': 'us6000rwe1'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.56,
#    'place': '10 km WSW of Stratford, CA',
#    'time': 1766356014840,
#    'updated': 1766356109465,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284381',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284381&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 101,
#    'net': 'nc',
#    'code': '75284381',
#    'ids': ',nc75284381,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.1534,
#    'rms': 0.03,
#    'gap': 192,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 10 km WSW of Stratford, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.925666809082, 36.156665802002, 14.7299995422363]},
#   'id': 'nc75284381'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': '5 km SE of San Ramon, CA',
#    'time': 1766356006520,
#    'updated': 1766356534220,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284376',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284376&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'nc',
#    'code': '75284376',
#    'ids': ',nc75284376,',
#    'sources': ',nc,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,',
#    'nst': 13,
#    'dmin': 0.09449,
#    'rms': 0.07,
#    'gap': 98,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 5 km SE of San Ramon, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.946334838867, 37.7478332519531, 9.47999954223633]},
#   'id': 'nc75284376'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.7,
#    'place': 'South Sandwich Islands region',
#    'time': 1766355937402,
#    'updated': 1766360446040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwe5',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwe5&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 340,
#    'net': 'us',
#    'code': '6000rwe5',
#    'ids': ',us6000rwe5,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 24,
#    'dmin': 5.356,
#    'rms': 0.94,
#    'gap': 94,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.7 - South Sandwich Islands region'},
#   'geometry': {'type': 'Point', 'coordinates': [-27.4016, -55.3061, 15.064]},
#   'id': 'us6000rwe5'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '37 km WSW of Manley Hot Springs, Alaska',
#    'time': 1766355764826,
#    'updated': 1766355866013,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak2025zbnoqq',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak2025zbnoqq&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ak',
#    'code': '2025zbnoqq',
#    'ids': ',ak2025zbnoqq,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.3,
#    'rms': 0.7,
#    'gap': 95,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 37 km WSW of Manley Hot Springs, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.342, 64.857, 9.4]},
#   'id': 'ak2025zbnoqq'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.24,
#    'place': '7 km NW of The Geysers, CA',
#    'time': 1766355688380,
#    'updated': 1766355785380,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284366',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284366&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 24,
#    'net': 'nc',
#    'code': '75284366',
#    'ids': ',nc75284366,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.008109,
#    'rms': 0.01,
#    'gap': 97,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 7 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.821502685547, 38.8143348693848, 2.01999998092651]},
#   'id': 'nc75284366'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '24 km SSW of Westbrook, Texas',
#    'time': 1766355270430,
#    'updated': 1766362695711,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025zbnhsj',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025zbnhsj&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'tx',
#    'code': '2025zbnhsj',
#    'ids': ',us6000rwdv,tx2025zbnhsj,',
#    'sources': ',us,tx,',
#    'types': ',origin,phase-data,',
#    'nst': 87,
#    'dmin': 0.2,
#    'rms': 0.4,
#    'gap': 81,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 24 km SSW of Westbrook, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.078, 32.142, 2.5509]},
#   'id': 'tx2025zbnhsj'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.12,
#    'place': '5 km SW of Ridgemark, CA',
#    'time': 1766354739220,
#    'updated': 1766354932190,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284361',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284361&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 69,
#    'net': 'nc',
#    'code': '75284361',
#    'ids': ',nc75284361,',
#    'sources': ',nc,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,',
#    'nst': 36,
#    'dmin': 0.03295,
#    'rms': 0.16,
#    'gap': 40,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 5 km SW of Ridgemark, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.410331726074, 36.7784996032715, 6.30999994277954]},
#   'id': 'nc75284361'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.02,
#    'place': '15 km WSW of Ludlow, CA',
#    'time': 1766354505950,
#    'updated': 1766354726370,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144815',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144815&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 16,
#    'net': 'ci',
#    'code': '41144815',
#    'ids': ',ci41144815,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.1263,
#    'rms': 0.13,
#    'gap': 78,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 15 km WSW of Ludlow, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.303, 34.6643333333333, 8.1]},
#   'id': 'ci41144815'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.44,
#    'place': '6 km WSW of Devore, CA',
#    'time': 1766354064390,
#    'updated': 1766354720040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144799',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144799&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 32,
#    'net': 'ci',
#    'code': '41144799',
#    'ids': ',ci41144799,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 60,
#    'dmin': 0.02919,
#    'rms': 0.16,
#    'gap': 55,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 6 km WSW of Devore, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.4625, 34.2098333333333, 13.67]},
#   'id': 'ci41144799'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.07,
#    'place': '7 km S of Olancha, CA',
#    'time': 1766353104930,
#    'updated': 1766353367109,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144783',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144783&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 18,
#    'net': 'ci',
#    'code': '41144783',
#    'ids': ',ci41144783,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 22,
#    'dmin': 0.1176,
#    'rms': 0.12,
#    'gap': 55,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 7 km S of Olancha, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-118.0105, 36.219, 3.92]},
#   'id': 'ci41144783'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.78,
#    'place': '5 km SW of Ridgemark, CA',
#    'time': 1766352942430,
#    'updated': 1766353038707,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284351',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284351&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 49,
#    'net': 'nc',
#    'code': '75284351',
#    'ids': ',nc75284351,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.03778,
#    'rms': 0.08,
#    'gap': 70,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 5 km SW of Ridgemark, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.406997680664, 36.7836685180664, 6.28999996185303]},
#   'id': 'nc75284351'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.4,
#    'place': '114 km N of Yakutat, Alaska',
#    'time': 1766352373916,
#    'updated': 1766355718040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwdr',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwdr&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': 3.832,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 178,
#    'net': 'us',
#    'code': '6000rwdr',
#    'ids': ',us6000rwdr,ak2025zblrxh,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,shakemap,',
#    'nst': 42,
#    'dmin': 0.563,
#    'rms': 0.88,
#    'gap': 68,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.4 - 114 km N of Yakutat, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-139.665, 60.5759, 5]},
#   'id': 'us6000rwdr'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.11,
#    'place': '9 km WNW of Cobb, CA',
#    'time': 1766352121060,
#    'updated': 1766352218458,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284331',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284331&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'nc',
#    'code': '75284331',
#    'ids': ',nc75284331,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.02584,
#    'rms': 0.36,
#    'gap': 229,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 9 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.819999694824, 38.8461685180664, -0.259999990463257]},
#   'id': 'nc75284331'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': '117 km WNW of Aykol, China',
#    'time': 1766351806049,
#    'updated': 1766355002040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwdq',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwdq&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 312,
#    'net': 'us',
#    'code': '6000rwdq',
#    'ids': ',us6000rwdq,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 72,
#    'dmin': 0.322,
#    'rms': 1.06,
#    'gap': 88,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - 117 km WNW of Aykol, China'},
#   'geometry': {'type': 'Point', 'coordinates': [78.8088, 41.2976, 10]},
#   'id': 'us6000rwdq'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.97,
#    'place': '8 km E of Santa Clarita, CA',
#    'time': 1766350473070,
#    'updated': 1766351875550,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144775',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144775&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 60,
#    'net': 'ci',
#    'code': '41144775',
#    'ids': ',ci41144775,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 98,
#    'dmin': 0.04774,
#    'rms': 0.21,
#    'gap': 19,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 8 km E of Santa Clarita, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.419166666667, 34.4045, 9.45]},
#   'id': 'ci41144775'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.43,
#    'place': '5 km SW of Ridgemark, CA',
#    'time': 1766350290480,
#    'updated': 1766350388312,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284311',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284311&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 31,
#    'net': 'nc',
#    'code': '75284311',
#    'ids': ',nc75284311,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.03839,
#    'rms': 0.07,
#    'gap': 106,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 5 km SW of Ridgemark, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.410331726074, 36.788501739502, 5.59000015258789]},
#   'id': 'nc75284311'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.94,
#    'place': '5 km SW of Ridgemark, CA',
#    'time': 1766350219800,
#    'updated': 1766350319372,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284306',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284306&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 58,
#    'net': 'nc',
#    'code': '75284306',
#    'ids': ',nc75284306,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.03634,
#    'rms': 0.09,
#    'gap': 100,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 5 km SW of Ridgemark, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.408332824707, 36.7826652526855, 7.28999996185303]},
#   'id': 'nc75284306'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.31,
#    'place': '3 km SE of San Ramon, CA',
#    'time': 1766349904690,
#    'updated': 1766350379245,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284296',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284296&format=geojson',
#    'felt': 0,
#    'cdi': 1,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'nc',
#    'code': '75284296',
#    'ids': ',nc75284296,',
#    'sources': ',nc,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.09015,
#    'rms': 0.02,
#    'gap': 143,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 3 km SE of San Ramon, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.956001281738, 37.7639999389648, 7.15000009536743]},
#   'id': 'nc75284296'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.9,
#    'place': '110 km N of Yakutat, Alaska',
#    'time': 1766349672908,
#    'updated': 1766352255040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwdm',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwdm&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 129,
#    'net': 'us',
#    'code': '6000rwdm',
#    'ids': ',us6000rwdm,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 33,
#    'dmin': 0.466,
#    'rms': 0.48,
#    'gap': 71,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.9 - 110 km N of Yakutat, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-139.9475, 60.5346, 8.497]},
#   'id': 'us6000rwdm'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.46,
#    'place': '5 km SW of Ridgemark, CA',
#    'time': 1766349649300,
#    'updated': 1766357203380,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284286',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284286&format=geojson',
#    'felt': 39,
#    'cdi': 3.6,
#    'mmi': 3.216,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 198,
#    'net': 'nc',
#    'code': '75284286',
#    'ids': ',nc75284286,us6000rwdl,',
#    'sources': ',nc,us,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,shakemap,',
#    'nst': 66,
#    'dmin': 0.03727,
#    'rms': 0.11,
#    'gap': 38,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.5 - 5 km SW of Ridgemark, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.40983581543, 36.7861671447754, 7.19000005722046]},
#   'id': 'nc75284286'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.64,
#    'place': '2 km SE of San Ramon, CA',
#    'time': 1766349599200,
#    'updated': 1766350503797,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284281',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284281&format=geojson',
#    'felt': 0,
#    'cdi': 1,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 41,
#    'net': 'nc',
#    'code': '75284281',
#    'ids': ',nc75284281,',
#    'sources': ',nc,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.08679,
#    'rms': 0.02,
#    'gap': 195,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 2 km SE of San Ramon, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.960502624512, 37.7641677856445, 6.6399998664856]},
#   'id': 'nc75284281'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.30807530540778,
#    'place': '13 km WNW of Calipatria, CA',
#    'time': 1766349453260,
#    'updated': 1766350599226,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144751',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144751&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ci',
#    'code': '41144751',
#    'ids': ',ci41144751,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.01651,
#    'rms': 0.109999999,
#    'gap': 102,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 13 km WNW of Calipatria, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.637664794922, 33.1725006103516, 2.49000000953674]},
#   'id': 'ci41144751'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.21,
#    'place': '5 km S of Highland, CA',
#    'time': 1766348758880,
#    'updated': 1766348994488,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144735',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144735&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '41144735',
#    'ids': ',ci41144735,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 51,
#    'dmin': 0.06096,
#    'rms': 0.19,
#    'gap': 53,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 5 km S of Highland, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.2125, 34.0878333333333, 5.21]},
#   'id': 'ci41144735'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '15 km W of Forsan, Texas',
#    'time': 1766346790973,
#    'updated': 1766362678894,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025zbiptp',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025zbiptp&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'tx',
#    'code': '2025zbiptp',
#    'ids': ',tx2025zbiptp,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 17,
#    'dmin': 0,
#    'rms': 0.4,
#    'gap': 75,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 15 km W of Forsan, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.528, 32.118, 4.857]},
#   'id': 'tx2025zbiptp'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.94,
#    'place': '11 km E of Cloverdale, CA',
#    'time': 1766346754640,
#    'updated': 1766346848687,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284246',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284246&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'nc',
#    'code': '75284246',
#    'ids': ',nc75284246,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.01743,
#    'rms': 0.11,
#    'gap': 153,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 11 km E of Cloverdale, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.891670227051, 38.8219985961914, -0.720000028610229]},
#   'id': 'nc75284246'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.12,
#    'place': '4 km SE of San Ramon, CA',
#    'time': 1766346668010,
#    'updated': 1766375998833,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284241',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284241&format=geojson',
#    'felt': 4,
#    'cdi': 2.6,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 70,
#    'net': 'nc',
#    'code': '75284241',
#    'ids': ',nc75284241,',
#    'sources': ',nc,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,',
#    'nst': 21,
#    'dmin': 0.08986,
#    'rms': 0.14,
#    'gap': 103,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 4 km SE of San Ramon, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.952667236328, 37.7506675720215, 8.89000034332275]},
#   'id': 'nc75284241'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.98,
#    'place': '21 km ESE of Anza, CA',
#    'time': 1766346527530,
#    'updated': 1766351830980,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144671',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144671&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'ci',
#    'code': '41144671',
#    'ids': ',ci41144671,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 38,
#    'dmin': 0.1097,
#    'rms': 0.13,
#    'gap': 66,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 21 km ESE of Anza, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.472333333333, 33.4785, 14.4]},
#   'id': 'ci41144671'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.47,
#    'place': '12 km W of Niland, CA',
#    'time': 1766346501200,
#    'updated': 1766353905641,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144663',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144663&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 33,
#    'net': 'ci',
#    'code': '41144663',
#    'ids': ',ci41144663,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 22,
#    'dmin': 0.04523,
#    'rms': 0.24,
#    'gap': 45,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 12 km W of Niland, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.642333333333, 33.2253333333333, 2.25]},
#   'id': 'ci41144663'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.1,
#    'place': '65 km NNE of Van Horn, Texas',
#    'time': 1766346357789,
#    'updated': 1766346654190,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025zbijnd',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025zbijnd&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 68,
#    'net': 'tx',
#    'code': '2025zbijnd',
#    'ids': ',tx2025zbijnd,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 30,
#    'dmin': 0.1,
#    'rms': 0.3,
#    'gap': 125,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 65 km NNE of Van Horn, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.593, 31.599, 2.435]},
#   'id': 'tx2025zbijnd'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '10 km WNW of Cobb, CA',
#    'time': 1766345886310,
#    'updated': 1766345983507,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284231',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284231&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'nc',
#    'code': '75284231',
#    'ids': ',nc75284231,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.008235,
#    'rms': 0.04,
#    'gap': 160,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 10 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.833000183105, 38.8513336181641, 0.0299999993294477]},
#   'id': 'nc75284231'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.3,
#    'place': '109 km S of Honchō, Japan',
#    'time': 1766345557625,
#    'updated': 1766347525040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwde',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwde&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 284,
#    'net': 'us',
#    'code': '6000rwde',
#    'ids': ',us6000rwde,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 41,
#    'dmin': 0.861,
#    'rms': 0.65,
#    'gap': 148,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.3 - 109 km S of Honchō, Japan'},
#   'geometry': {'type': 'Point', 'coordinates': [143.1026, 41.154, 47.858]},
#   'id': 'us6000rwde'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.92,
#    'place': '2 km WSW of Indios, Puerto Rico',
#    'time': 1766345500670,
#    'updated': 1766345837440,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71502798',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71502798&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 57,
#    'net': 'pr',
#    'code': '71502798',
#    'ids': ',pr71502798,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.04199,
#    'rms': 0.12,
#    'gap': 179,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 2 km WSW of Indios, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-66.838, 17.99, 14.21]},
#   'id': 'pr71502798'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.05,
#    'place': '4 km SW of Sunol, CA',
#    'time': 1766344924630,
#    'updated': 1766376025522,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284216',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284216&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 65,
#    'net': 'nc',
#    'code': '75284216',
#    'ids': ',nc75284216,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.1925,
#    'rms': 0.23,
#    'gap': 190,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 4 km SW of Sunol, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.925498962402, 37.5800018310547, 21.2700004577637]},
#   'id': 'nc75284216'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '63 km ESE of Denali National Park, Alaska',
#    'time': 1766343822283,
#    'updated': 1766343919013,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak2025zbgzcy',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak2025zbgzcy&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ak',
#    'code': '2025zbgzcy',
#    'ids': ',ak2025zbgzcy,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': 19,
#    'dmin': 0.7,
#    'rms': 0.7,
#    'gap': 46,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 63 km ESE of Denali National Park, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.5, 63.382, 6.4]},
#   'id': 'ak2025zbgzcy'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.43,
#    'place': '14 km W of Toms Place, CA',
#    'time': 1766340508260,
#    'updated': 1766340604352,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284191',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284191&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 31,
#    'net': 'nc',
#    'code': '75284191',
#    'ids': ',nc75284191,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.03593,
#    'rms': 0.05,
#    'gap': 115,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 14 km W of Toms Place, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.841163635254, 37.5553321838379, 7.40999984741211]},
#   'id': 'nc75284191'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.98,
#    'place': '18 km W of Union City, Oklahoma',
#    'time': 1766340042219,
#    'updated': 1766371404265,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2025yydt',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ok2025yydt&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 60,
#    'net': 'ok',
#    'code': '2025yydt',
#    'ids': ',ok2025yydt,',
#    'sources': ',ok,',
#    'types': ',origin,phase-data,',
#    'nst': 48,
#    'dmin': 0.09538128294,
#    'rms': 0.28,
#    'gap': 57,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 18 km W of Union City, Oklahoma'},
#   'geometry': {'type': 'Point', 'coordinates': [-98.14433333, 35.4095, 5.56]},
#   'id': 'ok2025yydt'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '98 km WNW of Yakutat, Alaska',
#    'time': 1766339735401,
#    'updated': 1766339832707,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak2025zbeskw',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak2025zbeskw&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'ak',
#    'code': '2025zbeskw',
#    'ids': ',ak2025zbeskw,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': 23,
#    'dmin': 0.3,
#    'rms': 0.9,
#    'gap': 160,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 98 km WNW of Yakutat, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-141.25, 59.994, 0.1]},
#   'id': 'ak2025zbeskw'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.6,
#    'place': '141 km E of Barcelona, Philippines',
#    'time': 1766339636946,
#    'updated': 1766348282075,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwcs',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwcs&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': 3.509,
#    'alert': 'green',
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 482,
#    'net': 'us',
#    'code': '6000rwcs',
#    'ids': ',usauto6000rwcs,pt25355002,us6000rwcs,',
#    'sources': ',usauto,pt,us,',
#    'types': ',internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#    'nst': 115,
#    'dmin': 2.476,
#    'rms': 1.19,
#    'gap': 36,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.6 - 141 km E of Barcelona, Philippines'},
#   'geometry': {'type': 'Point', 'coordinates': [127.6988, 8.3893, 9]},
#   'id': 'us6000rwcs'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.34,
#    'place': '3 km S of Cobb, CA',
#    'time': 1766339171370,
#    'updated': 1766339267949,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284186',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284186&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'nc',
#    'code': '75284186',
#    'ids': ',nc75284186,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.01526,
#    'rms': 0.04,
#    'gap': 233,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 3 km S of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.722663879395, 38.7938346862793, 2.21000003814697]},
#   'id': 'nc75284186'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '93 km SW of Jiquilillo, Nicaragua',
#    'time': 1766338916897,
#    'updated': 1766343423040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rwcq',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rwcq&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 298,
#    'net': 'us',
#    'code': '6000rwcq',
#    'ids': ',us6000rwcq,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 22,
#    'dmin': 1.146,
#    'rms': 0.7,
#    'gap': 195,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 93 km SW of Jiquilillo, Nicaragua'},
#   'geometry': {'type': 'Point', 'coordinates': [-88.0438, 12.1314, 35.924]},
#   'id': 'us6000rwcq'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.09,
#    'place': '4 km SE of San Ramon, CA',
#    'time': 1766338516750,
#    'updated': 1766344771123,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75284181',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75284181&format=geojson',
#    'felt': 2,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 68,
#    'net': 'nc',
#    'code': '75284181',
#    'ids': ',nc75284181,',
#    'sources': ',nc,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.09642,
#    'rms': 0.04,
#    'gap': 74,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 4 km SE of San Ramon, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.94416809082, 37.7498321533203, 9.11999988555908]},
#   'id': 'nc75284181'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '14 km SSW of Big Spring, Texas',
#    'time': 1766338271476,
#    'updated': 1766362657964,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025zbdxke',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025zbdxke&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'tx',
#    'code': '2025zbdxke',
#    'ids': ',tx2025zbdxke,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 34,
#    'dmin': 0,
#    'rms': 0.3,
#    'gap': 84,
#    'magType': 'ml',
# ...
#    'rms': 0.16,
#    'gap': 32,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 1 km NNE of Loma Linda, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.255, 34.0586666666667, 12.17]},
#   'id': 'ci41144247'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.8,
#    'place': '2 km SSW of Magas Arriba, Puerto Rico',
#    'time': 1766281275040,
#    'updated': 1766282425990,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71502733',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71502733&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 121,
#    'net': 'pr',
#    'code': '71502733',
#    'ids': ',pr71502733,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 25,
#    'dmin': 0.02549,
#    'rms': 0.26,
#    'gap': 140,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 2 km SSW of Magas Arriba, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.7816666666667, 17.9961666666667, 13.1]},
#   'id': 'pr71502733'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.03,
#    'place': '14 km E of Ocotillo Wells, CA',
#    'time': 1766280848390,
#    'updated': 1766327668180,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144239',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144239&format=geojson',
#    'felt': 1,
#    'cdi': 0,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 63,
#    'net': 'ci',
#    'code': '41144239',
#    'ids': ',ci41144239,',
#    'sources': ',ci,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 71,
#    'dmin': 0.01313,
#    'rms': 0.21,
#    'gap': 26,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 14 km E of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.977333333333, 33.1603333333333, 7.37]},
#   'id': 'ci41144239'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '8 km ENE of Pinnacles, CA',
#    'time': 1766280621620,
#    'updated': 1766280720955,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75283661',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75283661&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'nc',
#    'code': '75283661',
#    'ids': ',nc75283661,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.02517,
#    'rms': 0.1,
#    'gap': 99,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 8 km ENE of Pinnacles, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.060836791992, 36.560001373291, 1.49000000953674]},
#   'id': 'nc75283661'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.4,
#    'place': '59 km ENE of Hachinohe, Japan',
#    'time': 1766280543210,
#    'updated': 1766368190772,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rw94',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rw94&format=geojson',
#    'felt': 3,
#    'cdi': 3.8,
#    'mmi': 4.006,
#    'alert': 'green',
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 450,
#    'net': 'us',
#    'code': '6000rw94',
#    'ids': ',us6000rw94,usauto6000rw94,pt25355000,',
#    'sources': ',us,usauto,pt,',
#    'types': ',dyfi,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,',
#    'nst': 65,
#    'dmin': 0.785,
#    'rms': 0.88,
#    'gap': 82,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.4 - 59 km ENE of Hachinohe, Japan'},
#   'geometry': {'type': 'Point', 'coordinates': [142.0989, 40.7769, 55.354]},
#   'id': 'us6000rw94'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.45,
#    'place': '10 km S of Ojai, CA',
#    'time': 1766280064900,
#    'updated': 1766280295017,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144231',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144231&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 32,
#    'net': 'ci',
#    'code': '41144231',
#    'ids': ',ci41144231,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 28,
#    'dmin': 0.045,
#    'rms': 0.29,
#    'gap': 88,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 10 km S of Ojai, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-119.263166666667, 34.3628333333333, 8.45]},
#   'id': 'ci41144231'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '20 km NW of Stanton, Texas',
#    'time': 1766280061846,
#    'updated': 1766319496201,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025yzxtjf',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025yzxtjf&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'tx',
#    'code': '2025yzxtjf',
#    'ids': ',tx2025yzxtjf,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 54,
#    'dmin': 0,
#    'rms': 0.4,
#    'gap': 29,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 20 km NW of Stanton, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.958, 32.241, 4.0365]},
#   'id': 'tx2025yzxtjf'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.33,
#    'place': '4 km NW of The Geysers, CA',
#    'time': 1766279806460,
#    'updated': 1766279904418,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75283656',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75283656&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'nc',
#    'code': '75283656',
#    'ids': ',nc75283656,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.008399,
#    'rms': 0.01,
#    'gap': 78,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.3 - 4 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.78483581543, 38.8055000305176, 3.39000010490417]},
#   'id': 'nc75283656'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '7 km NW of The Geysers, CA',
#    'time': 1766278715590,
#    'updated': 1766278809618,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75283646',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75283646&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'nc',
#    'code': '75283646',
#    'ids': ',nc75283646,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 17,
#    'dmin': 0.01054,
#    'rms': 0.03,
#    'gap': 70,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 7 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.817337036133, 38.8144989013672, 0.920000016689301]},
#   'id': 'nc75283646'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.68,
#    'place': '2 km NE of Lluveras, Puerto Rico',
#    'time': 1766278518580,
#    'updated': 1766279414900,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71502723',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71502723&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 43,
#    'net': 'pr',
#    'code': '71502723',
#    'ids': ',pr71502723,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.07764,
#    'rms': 0.13,
#    'gap': 86,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 2 km NE of Lluveras, Puerto Rico'},
#   'geometry': {'type': 'Point', 'coordinates': [-66.8895, 18.0525, 11.08]},
#   'id': 'pr71502723'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.92,
#    'place': '7 km ESE of Yucaipa, CA',
#    'time': 1766278306960,
#    'updated': 1766278520699,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144223',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144223&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 13,
#    'net': 'ci',
#    'code': '41144223',
#    'ids': ',ci41144223,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 31,
#    'dmin': 0.08712,
#    'rms': 0.17,
#    'gap': 43,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 7 km ESE of Yucaipa, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.970166666667, 34.011, 13.9]},
#   'id': 'ci41144223'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.17,
#    'place': '8 km ESE of Yucaipa, CA',
#    'time': 1766278116400,
#    'updated': 1766342169410,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41144215',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41144215&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 72,
#    'net': 'ci',
#    'code': '41144215',
#    'ids': ',ci41144215,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 100,
#    'dmin': 0.08703,
#    'rms': 0.18,
#    'gap': 20,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 8 km ESE of Yucaipa, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.966333333333, 34.0078333333333, 14.52]},
#   'id': 'ci41144215'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.72,
#    'place': '13 km SSW of Tres Pinos, CA',
#    'time': 1766277722240,
#    'updated': 1766277820503,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75283631',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75283631&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 46,
#    'net': 'nc',
#    'code': '75283631',
#    'ids': ',nc75283631,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 23,
#    'dmin': 0.02893,
#    'rms': 0.16,
#    'gap': 53,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 13 km SSW of Tres Pinos, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.347999572754, 36.6785011291504, 1.19000005722046]},
#   'id': 'nc75283631'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.31,
#    'place': '3 km SE of San Ramon, CA',
#    'time': 1766277708780,
#    'updated': 1766277860163,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75283636',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75283636&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'nc',
#    'code': '75283636',
#    'ids': ',nc75283636,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.0913,
#    'rms': 0.01,
#    'gap': 201,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 3 km SE of San Ramon, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.952331542969, 37.7573318481445, 7.48000001907349]},
#   'id': 'nc75283636'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.5,
#    'place': '60 km W of Nanwalek, Alaska',
#    'time': 1766277534409,
#    'updated': 1766278450040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak2025yzwjcf',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak2025yzwjcf&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 96,
#    'net': 'ak',
#    'code': '2025yzwjcf',
#    'ids': ',us6000rw92,ak2025yzwjcf,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,',
#    'nst': 45,
#    'dmin': 0.6,
#    'rms': 0.7,
#    'gap': 100,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 60 km W of Nanwalek, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.98, 59.398, 75.9]},
#   'id': 'ak2025yzwjcf'},
#  {'type': 'Feature',
#   'properties': {'mag': 5,
#    'place': '91 km ESE of Shikotan, Russia',
#    'time': 1766276544358,
#    'updated': 1766278071040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rw90',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rw90&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 385,
#    'net': 'us',
#    'code': '6000rw90',
#    'ids': ',us6000rw90,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 81,
#    'dmin': 3.809,
#    'rms': 0.78,
#    'gap': 110,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 5.0 - 91 km ESE of Shikotan, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [147.8416, 43.6396, 34.683]},
#   'id': 'us6000rw90'},
#  {'type': 'Feature',
#   'properties': {'mag': 5,
#    'place': '119 km ESE of Shikotan, Russia',
#    'time': 1766276340634,
#    'updated': 1766277503040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000rw8v',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000rw8v&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 385,
#    'net': 'us',
#    'code': '6000rw8v',
#    'ids': ',us6000rw8v,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 85,
#    'dmin': 3.826,
#    'rms': 1,
#    'gap': 102,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 5.0 - 119 km ESE of Shikotan, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [148.037, 43.3158, 10]},
#   'id': 'us6000rw8v'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '85 km N of Yakutat, Alaska',
#    'time': 1766275981651,
#    'updated': 1766276153080,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak2025yzvmul',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak2025yzvmul&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'ak',
#    'code': '2025yzvmul',
#    'ids': ',ak2025yzvmul,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.3,
#    'rms': 0.6,
#    'gap': 110,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 85 km N of Yakutat, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-139.944, 60.304, 3.6]},
#   'id': 'ak2025yzvmul'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.33,
#    'place': '5 km SSE of Quilcene, Washington',
#    'time': 1766275861830,
#    'updated': 1766283634020,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62210992',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62210992&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 27,
#    'net': 'uw',
#    'code': '62210992',
#    'ids': ',uw62210992,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 13,
#    'dmin': 0.05655,
#    'rms': 0.19,
#    'gap': 66,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 5 km SSE of Quilcene, Washington'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.842, 47.78066666666667, 21.03]},
#   'id': 'uw62210992'}]

# %%
# Define your variables
output_data = {
    "start_date": start_date,
    "end_date": end_date,
    "bronze_adls": bronze_adls,
    "silver_adls": silver_adls,
    "gold_adls": gold_adls
}

# Serialize the dictionary to a JSON string
output_json = json.dumps(output_data)

# Log the serialized JSON for debugging
print(f"Serialized JSON: {output_json}")

# Return the JSON string
dbutils.notebook.exit(output_json)
